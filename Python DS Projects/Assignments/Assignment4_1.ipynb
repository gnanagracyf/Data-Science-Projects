# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ODN_Education.csv')

# %%
state = df['name'].unique()
state
# Out:
# array(['Bruning village, Nebraska', 'Westlake city, Louisiana',
#        'Low Moor CDP, Virginia', ..., '60152 ZIP Code', '93726 ZIP Code',
#        'Fieldbrook CDP, California'], dtype=object)

# %%
df1 = pd.read_csv('Financial_Metrics.csv')
df1 = df1.loc[(df1['variable'] == 'total_general_fund_revenue') | (df1['variable'] == 'total_general_fund_revenues')]
df1 = df1.groupby('year').sum()
df1 = df1['value']
#df1 = df1.rename(columns={'value':'Revenue'})
df1 = df1.to_frame()
df1 = df1.rename(columns={'value':'Revenue'})
df1
# Out:
#            Revenue
# year
# 2010  1.644357e+10
# 2011  1.636678e+10
# 2012  1.659623e+10
# 2013  1.606808e+10
# 2014  1.652964e+10
# 2015  1.950883e+10
# 2016  1.723272e+10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# use the 'seaborn-colorblind' style
plt.style.use('seaborn-colorblind')
#df1.plot.kde();

import seaborn as sns
plt.figure()
df1.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# df1.head()

# %%
df2 = pd.read_csv('Yearly_Unemployment_Rate.csv')

# %%
df2.set_index('Year',inplace=True)

# %%
#df2 = df2['Michigan Unemployment'].str.rstrip('%')

#df[0] = df[0].str.strip()

# %%
df2 = df2.str.rstrip('%').apply(pd.to_numeric)

# %%
df2.sort_index(inplace=True)
df2 = df2[10:]

# %%
plt.figure()
df1.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#plt.figure()
#sns.jointplot(df1, df2, alpha=0.4);

# %%
#plt.figure()
# set the seaborn style for all the following plots
#sns.set_style('white')

#sns.jointplot(df1, df2, kind='kde', space=0);

# %%
df1
# Out:
#            Revenue
# year
# 2010  1.644357e+10
# 2011  1.636678e+10
# 2012  1.659623e+10
# 2013  1.606808e+10
# 2014  1.652964e+10
# 2015  1.950883e+10
# 2016  1.723272e+10

# %%
df2
# Out:
#       Michigan Unemployment
# Year
# 2010                   12.6
# 2011                   10.4
# 2012                    9.1
# 2013                    8.8
# 2014                    7.3
# 2015                    5.4
# 2016                    4.9

# %%
plt.figure()
df1.plot(kind='hist');
#fig, ax = plt.subplots()
#sns.distplot(df2)


#ax2 = ax.twinx()
#sns.regplot(data=df2, ax=ax2, color='r')
#sns.plt.show()
#sns.distplot(df1, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'});
# set the seaborn style for all the following plots
#sns.set_style('white')

#sns.jointplot(df1, df2, kind='kde', space=0);
#plt.figure(figsize=(8,6))
#plt.subplot(121)
#sns.swarmplot(df1, df2);
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
result = pd.concat([df1, df2], axis=1)

# %%
result
# Out:
#            Revenue  Michigan Unemployment
# 2010  1.644357e+10                   12.6
# 2011  1.636678e+10                   10.4
# 2012  1.659623e+10                    9.1
# 2013  1.606808e+10                    8.8
# 2014  1.652964e+10                    7.3
# 2015  1.950883e+10                    5.4
# 2016  1.723272e+10                    4.9

# %%
plt.figure()

sns.kdeplot(result);
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Gracy\Anaconda2\lib\site-packages\seaborn\distributions.py:630: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
plt.figure()
fig, ax = plt.subplots()
df1.plot(ax=ax)
ax2 = ax.twinx()
df2.plot(ax=ax2,color='red')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.jointplot(x="Revenue", y="Michigan Unemployment", data=result);
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="600">

# %%
result
# Out:
#            Revenue  Michigan Unemployment
# 2010  1.644357e+10                   12.6
# 2011  1.636678e+10                   10.4
# 2012  1.659623e+10                    9.1
# 2013  1.606808e+10                    8.8
# 2014  1.652964e+10                    7.3
# 2015  1.950883e+10                    5.4
# 2016  1.723272e+10                    4.9
