# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split("(") # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#               № Summer  Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Afghanistan         13     0       0       2      2         0       0
# Algeria             12     5       2       8     15         3       0
# Argentina           23    18      24      28     70        18       0
# Armenia              5     1       2       9     12         6       0
# Australasia          2     3       4       5     12         0       0
#
#               Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Afghanistan          0         0        0       13       0         0
# Algeria              0         0        0       15       5         2
# Argentina            0         0        0       41      18        24
# Armenia              0         0        0       11       1         2
# Australasia          0         0        0        2       3         4
#
#               Bronze.2  Combined total   ID
# Afghanistan          2               2  AFG
# ...

# %%
def answer_zero():
    # This function returns the row for Afghanistan, which is a Series object. The assignment
    # question description will tell you the general format the autograder is expecting
    return df.iloc[0]

# You can examine what your function returns by calling it in the cell. If you have questions
# about the assignment formats, check out the discussion forums for any FAQs
s = answer_zero()

# %%
def answer_one():    
    return (df.loc[df['Gold'] == df['Gold'].max()]).index.values[0].replace('\xc2\xa0','')

# %%
answer_one()
# Out:
# 'United States'

# %%
def answer_two():
    df['diff'] = df['Gold'] - df['Gold.1']    
    return df.loc[df['diff'] == df['diff'].max()].index.values[0].replace('\xc2\xa0','')

# %%
answer_two()
# Out:
# 'United States'

# %%
def answer_three():
    df = df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
    df['diff'] = (df['Gold'] - df['Gold.1'])/df['Combined total']      
    return df.loc[df['diff'] == df['diff'].max()].index.values[0].replace('\xc2\xa0','')

# %%
answer_three()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-543-60bcab5403a9> in <module>()
# ----> 1 answer_three()
#
# <ipython-input-542-e3828ce77733> in answer_three()
#       1 def answer_three():
# ----> 2     df = df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
#       3     df['diff'] = (df['Gold'] - df['Gold.1'])/df['Combined total']
#       4     return df.loc[df['diff'] == df['diff'].max()].index.values[0].replace('\xc2\xa0','')
#
# UnboundLocalError: local variable 'df' referenced before assignment

# %%
df = df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]

df['diff'] = (df['Gold'] - df['Gold.1'])/df['Combined total']

# %%
df.loc[df['diff'] == df['diff'].max()].index.values[0].replace('\xc2\xa0','')
# Out:
# 'China'

# %%
def answer_three():
    df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
    df.loc['diff'] = (df['Gold'] - df['Gold.1'])/df['Combined total']      
    return df.loc[df['diff'] == df['diff'].max()].index.values[0].replace('\xc2\xa0','')

# %%
df.loc[:,'diff'] = (df['Gold'] - df['Gold.1'])/df['Combined total']
df
# Out:
#                          № Summer   Gold  Silver  Bronze   Total  № Winter  \
# Australia                    25.0  139.0   152.0   177.0   468.0      18.0
# Austria                      26.0   18.0    33.0    35.0    86.0      22.0
# Belarus                       5.0   12.0    24.0    39.0    75.0       6.0
# Belgium                      25.0   37.0    52.0    53.0   142.0      20.0
# Bulgaria                     19.0   51.0    85.0    78.0   214.0      19.0
# Canada                       25.0   59.0    99.0   121.0   279.0      22.0
# China                         9.0  201.0   146.0   126.0   473.0      10.0
# Croatia                       6.0    6.0     7.0    10.0    23.0       7.0
# Czech Republic                5.0   14.0    15.0    15.0    44.0       6.0
# Czechoslovakia               16.0   49.0    49.0    45.0   143.0      16.0
# Estonia                      11.0    9.0     9.0    15.0    33.0       9.0
# ...

# %%
df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
# Out:
#                          № Summer   Gold  Silver  Bronze   Total  № Winter  \
# Australia                    25.0  139.0   152.0   177.0   468.0      18.0
# Austria                      26.0   18.0    33.0    35.0    86.0      22.0
# Belarus                       5.0   12.0    24.0    39.0    75.0       6.0
# Belgium                      25.0   37.0    52.0    53.0   142.0      20.0
# Bulgaria                     19.0   51.0    85.0    78.0   214.0      19.0
# Canada                       25.0   59.0    99.0   121.0   279.0      22.0
# China                         9.0  201.0   146.0   126.0   473.0      10.0
# Croatia                       6.0    6.0     7.0    10.0    23.0       7.0
# Czech Republic                5.0   14.0    15.0    15.0    44.0       6.0
# Czechoslovakia               16.0   49.0    49.0    45.0   143.0      16.0
# Estonia                      11.0    9.0     9.0    15.0    33.0       9.0
# ...

# %%
df
# Out:
#                          № Summer   Gold  Silver  Bronze   Total  № Winter  \
# Australia                    25.0  139.0   152.0   177.0   468.0      18.0
# Austria                      26.0   18.0    33.0    35.0    86.0      22.0
# Belarus                       5.0   12.0    24.0    39.0    75.0       6.0
# Belgium                      25.0   37.0    52.0    53.0   142.0      20.0
# Bulgaria                     19.0   51.0    85.0    78.0   214.0      19.0
# Canada                       25.0   59.0    99.0   121.0   279.0      22.0
# China                         9.0  201.0   146.0   126.0   473.0      10.0
# Croatia                       6.0    6.0     7.0    10.0    23.0       7.0
# Czech Republic                5.0   14.0    15.0    15.0    44.0       6.0
# Czechoslovakia               16.0   49.0    49.0    45.0   143.0      16.0
# Estonia                      11.0    9.0     9.0    15.0    33.0       9.0
# ...

# %%
df1 = df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]

# %%
df1.loc[:,'diff'] =  (df1['Gold'] - df1['Gold.1']) / df1['Combined total']

# %%
def answer_three():
    df1 = df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
    df1.loc[:,'diff'] = (df1['Gold'] - df1['Gold.1']) / df1['Combined total']      
    return df1.loc[df1['diff'] == df1['diff'].max()].index.values[0].replace('\xc2\xa0','')

# %%
df1 = df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
df1.loc[:,'diff'] = (df1['Gold'] - df1['Gold.1']) / df1['Combined total']      
#df1.loc[df1['diff'] == df1['diff'].max()].values[0].replace('\xc2\xa0','')

# %%
df1.loc[df1['diff'] == df1['diff'].max()].index.values[0].replace('\xc2\xa0','')
# Out:
# 'China'

# %%
answer_three()
# Out:
# 'China'

# %%
def answer_four():
    Points = pd.Series([3, 2, 1], index=['Gold.2', 'Silver.2', 'Bronze.2'])
    return Points

# %%
p = answer_four()

# %%
p.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-604-4e54c33b19a7> in <module>()
# ----> 1 p.size()
#
# TypeError: 'int' object is not callable
