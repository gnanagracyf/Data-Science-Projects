# %%
#Question 8

#In this datafile, the United States is broken up into four regions using the "REGION" column.

#Create a query that finds the counties that belong to regions 1 or 2, whose name starts with 'Washington', 
#and whose POPESTIMATE2015 was greater than their POPESTIMATE 2014.

#This function should return a 5x2 DataFrame with the columns = ['STNAME', 'CTYNAME'] 
#and the same index ID as the census_df (sorted ascending by index).

# %%
census_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-de43148d0a7e> in <module>()
# ----> 1 census_df
#
# NameError: name 'census_df' is not defined

# %%
import pandas as pd
census_df = pd.read_csv('census.csv')
census_df
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME         CTYNAME  \
# 0       40       3         6      1       0     Alabama         Alabama
# 1       50       3         6      1       1     Alabama  Autuaga County
# 2       50       3         6      1       3     Alabama  Baldwin County
# 3       50       3         6      1       5     Alabama  Barbour County
# 4       50       3         6      1       7     Alabama     Bibb County
# 5       40       4         4      2       0    Michigan        Michigan
# 6       50       4         5      3       1    Michigan          mickey
# 7       50       4         6      2       2    Michigan           Mouse
# 8       50       1         4      2       4  Washington   Washington DC
# 9       50       1         4      2       5  Washington   Washington MC
# 10      50       2         4      2       5  Washington   Washington MC
# 11      50       2         4      2       5  Washington   Washington MC
#
# ...

# %%
# select rows with SUMLEV = 50
census_df = census_df[census_df.SUMLEV != 40]

# %%
census_df[census_df.REGION = 1]
# Out:
#   File "<ipython-input-12-8f3e7cf6d8c7>", line 1
#     census_df[census_df.REGION = 1]
#                                ^
# SyntaxError: invalid syntax

# %%
census_df[(census_df['REGION'] == 1) & (census_df['REGION'] == 2)]
# Out:
# Empty DataFrame
# Columns: [SUMLEV, REGION, DIVISION, STATE, COUNTY, STNAME, CTYNAME, CENSUS2010POP, ESTIMATESBASE2010, POPESTIMATE2010, POPESTIMATE2011, POPESTIMATE2012, POPESTIMATE2013, POPESTIMATE2014, POPESTIMATE2015]
# Index: []

# %%
([census_df['REGION'] == 1) & (census_df['REGION'] == 2])
# Out:
#   File "<ipython-input-18-df663cc45d80>", line 1
#     ([census_df['REGION'] == 1) & (census_df['REGION'] == 2])
#                               ^
# SyntaxError: invalid syntax

# %%
census_df[census_df['REGION'] == 1]
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME CTYNAME  CENSUS2010POP  \
# 8      NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 9      NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 10     NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 11     NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
#
#     ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 8                 NaN              NaN              NaN              NaN
# 9                 NaN              NaN              NaN              NaN
# 10                NaN              NaN              NaN              NaN
# 11                NaN              NaN              NaN              NaN
#
#     POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 8               NaN              NaN              NaN
# 9               NaN              NaN              NaN
# 10              NaN              NaN              NaN
# ...

# %%
census_df[((census_df['REGION'] == 1) | (census_df['REGION'] == 2) ) & (census_df['CTYNAME'].str.startswith('Washington')) & (census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])]
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME        CTYNAME  \
# 9      50       1         4      2       5  Washington  Washington MC
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 9          13442                234              234            234.0
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 9           2454.0          14234.0           123456     8.776390e+24

# %%
census_df['CTYNAME'].str.startswith('Washington')
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# Name: CTYNAME, dtype: bool

# %%
census_df = census_df[(census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])]

# %%
census_df = pd.read_csv('census.csv')
census_df
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME         CTYNAME  \
# 0       40       3         6      1       0     Alabama         Alabama
# 1       50       3         6      1       1     Alabama  Autuaga County
# 2       50       3         6      1       3     Alabama  Baldwin County
# 3       50       3         6      1       5     Alabama  Barbour County
# 4       50       3         6      1       7     Alabama     Bibb County
# 5       40       4         4      2       0    Michigan        Michigan
# 6       50       4         5      3       1    Michigan          mickey
# 7       50       4         6      2       2    Michigan           Mouse
# 8       50       1         4      2       4  Washington   Washington DC
# 9       50       1         4      2       5  Washington   Washington MC
# 10      50       2         4      2       5  Washington   Washington MC
# 11      50       2         4      2       5  Washington   Washington MC
#
# ...

# %%
census_df = census_df[(census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])]

# %%
census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME         CTYNAME  \
# 2      50       3         6      1       3     Alabama  Baldwin County
# 3      50       3         6      1       5     Alabama  Barbour County
# 7      50       4         6      2       2    Michigan           Mouse
# 9      50       1         4      2       5  Washington   Washington MC
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 2          36456              34343            34343        1231234.0
# 3          34353              34343            34343          56564.0
# 7         454656              64453             6342         345345.0
# 9          13442                234              234            234.0
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 2             53.0         867867.0            42342     2.342323e+08
# 3         345345.0        7867867.0              423     2.342300e+04
# ...

# %%
df = census_df[((census_df['REGION'] == 1) | (census_df['REGION'] == 2) ) & (census_df['CTYNAME'].str.startswith('Washington')) & (census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])]

# %%
df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME        CTYNAME  \
# 9      50       1         4      2       5  Washington  Washington MC
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 9          13442                234              234            234.0
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 9           2454.0          14234.0           123456     8.776390e+24

# %%
df[['STNAME','CTYNAME']].sort_values('',axis=0,ascending=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-13e47049a9a1> in <module>()
# ----> 1 df[['STNAME','CTYNAME']].sort_values(by='id', ascending=False, inplace=True)
#       2 get_ipython().magic(u'pinfo df.sort_values')
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3184
#    3185             by = by[0]
# -> 3186             k = self.xs(by, axis=other_axis).values
#    3187             if k.ndim == 2:
#    3188
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\generic.pyc in xs(self, key, axis, level, drop_level)
#    2021
#    2022         if axis == 1:
# -> 2023             return self[key]
#    2024
#    2025         self._consolidate_inplace()
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
# ...

# %%
census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME         CTYNAME  \
# 2      50       3         6      1       3     Alabama  Baldwin County
# 3      50       3         6      1       5     Alabama  Barbour County
# 7      50       4         6      2       2    Michigan           Mouse
# 9      50       1         4      2       5  Washington   Washington MC
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 2          36456              34343            34343        1231234.0
# 3          34353              34343            34343          56564.0
# 7         454656              64453             6342         345345.0
# 9          13442                234              234            234.0
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 2             53.0         867867.0            42342     2.342323e+08
# 3         345345.0        7867867.0              423     2.342300e+04
# ...

# %%
census_df.sort_index(axis=0, level=None, ascending=True, inplace=True)

# %%
census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME         CTYNAME  \
# 2      50       3         6      1       3     Alabama  Baldwin County
# 3      50       3         6      1       5     Alabama  Barbour County
# 7      50       4         6      2       2    Michigan           Mouse
# 9      50       1         4      2       5  Washington   Washington MC
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 2          36456              34343            34343        1231234.0
# 3          34353              34343            34343          56564.0
# 7         454656              64453             6342         345345.0
# 9          13442                234              234            234.0
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 2             53.0         867867.0            42342     2.342323e+08
# 3         345345.0        7867867.0              423     2.342300e+04
# ...
