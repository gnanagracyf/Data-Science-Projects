# %%
import pandas as pd
census_df = pd.read_csv('census.csv')
census_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
census_df = census_df[census_df.SUMLEV != 40]

# %%
census_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
def answer_five():
    df = census_df.groupby("STNAME").size().reset_index().set_index('STNAME')
    df.rename(columns={ 0 : 'Count'},inplace=True)
    s = df.loc[ df['Count'] == df['Count'].max()].index.values[0]
    return s

# %%
df = census_df.groupby("STNAME").size().reset_index().set_index('STNAME')

df.rename(columns={ 0 : 'Count'},inplace=True)
df
df.loc[ df['Count'] == df['Count'].max()].index.values[0]
#s= df.loc[df['Count'] == df['Count'].max()]
#df['STNAME']
#df.index[df.max()].tolist()
# Out:
# 'Texas'

# %%
answer_five()
# Out:
# 'Texas'

# %%
def answer_seven():
    census_df["max_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].max(axis=1)
    df_result = census_df.sort_values("max_val",ascending=False).head(1)   
    return df_result["CTYNAME"][0]

# %%
def answer_eight():
    census_df[((census_df['REGION'] == 1) | (census_df['REGION'] == 2) ) & (census_df['CTYNAME'].str.startswith('Washington')) & (census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])].head(5)    
    census_df.sort_index(axis=0, level=None, ascending=True, inplace=True)
    return census_df

# %%
census_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
answer_five()
# Out:
# 'Wyoming'

# %%
def answer_five():
    s=census_df.groupby("STNAME").size().reset_index().max()  
    return s.loc['STNAME']

# %%
 census_df.groupby("STNAME").max()
# Out:
#                       SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME
# Alabama                   50       3         6      1     133
# Alaska                    50       4         9      2     290
# Arizona                   50       4         8      4      27
# Arkansas                  50       3         7      5     149
# California                50       4         9      6     115
# Colorado                  50       4         8      8     125
# Connecticut               50       1         1      9      15
# Delaware                  50       3         5     10       5
# District of Columbia      50       3         5     11       1
# Florida                   50       3         5     12     133
# Georgia                   50       3         5     13     321
# Hawaii                    50       4         9     15       9
# Idaho                     50       4         8     16      87
# Illinois                  50       2         3     17     203
# ...

# %%
def answer_six():
    census_df = census_df[census_df.SUMLEV != 40]    
    return census_df.groupby('STNAME').apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3).loc[:,['STNAME','CTYNAME']].values.tolist()

# %%
census_df.groupby('STNAME).apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False))
# Out:
#   File "<ipython-input-216-eb407c2a679a>", line 1
#     census_df.groupby('STNAME).apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False))
#                                                                          ^
# SyntaxError: invalid syntax

# %%
df1 = ((census_df.groupby('STNAME').apply(lambda x : x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3)).loc[:,['CENSUS2010POP']])

# %%
df1.groupby('STNAME').apply(lambda x:x['CENSUS2010POP'].sum()).sort_values(0,ascending=False).head(3).index.values.tolist()
# Out:
# ['California', 'Texas', 'Illinois']

# %%
def answer_six():
    census_df[census_df.SUMLEV != 40]
    df1 = ((census_df.groupby('STNAME').apply(lambda x : x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3)).loc[:,['CENSUS2010POP']]) 
    return df1.groupby('STNAME').apply(lambda x:x['CENSUS2010POP'].sum()).sort_values(0,ascending=False).head(3).index.values.tolist()

# %%
answer_six()
# Out:
# ['California', 'Texas', 'Illinois']

# %%
census_df = census_df[census_df.SUMLEV != 40]

# %%
def answer_six():
    census_df[census_df.SUMLEV != 40]
    df1 = ((census_df.groupby('STNAME').apply(lambda x : x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3)).loc[:,['CENSUS2010POP']]) 
    return df1.groupby('STNAME').apply(lambda x:x['CENSUS2010POP'].sum()).sort_values(0,ascending=False).head(3).index.values.tolist()

# %%
answer_six()
# Out:
# ['California', 'Texas', 'Illinois']

# %%
def answer_seven():
    census_df["max_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].max(axis=1)
    census_df["min_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].min(axis=1)
    census_df["val_diff"] = census_df["max_val"] - census_df["min_val"]
    df_result = census_df.sort_values("val_diff",ascending=False).head(1)   
    return df_result

# %%
census_df["max_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].max(axis=1)
census_df["min_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].min(axis=1)
census_df["val_diff"] = census_df["max_val"] - census_df["min_val"]
census_df.sort_values("val_diff",ascending=False).head(1).set_index('STNAME').index.values[0]
# Out:
# 'Texas'

# %%
def answer_seven():
    census_df["max_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].max(axis=1)
    census_df["min_val"] = census_df[["POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013","POPESTIMATE2014","POPESTIMATE2015"]].min(axis=1)
    census_df["val_diff"] = census_df["max_val"] - census_df["min_val"]
    s = census_df.sort_values("val_diff",ascending=False).head(1).set_index('STNAME').index.values[0]  
    return s

# %%
answer_seven()
# Out:
# 'Texas'

# %%
def answer_eight():
    census_df[((census_df['REGION'] == 1) | (census_df['REGION'] == 2) ) & (census_df['CTYNAME'].str.startswith('Washington')) & (census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])].head(5)    
    census_df.sort_index(axis=0, level=None, ascending=True, inplace=True)
    return census_df

# %%
census_df[census_df.SUMLEV != 40]
df = census_df[((census_df['REGION'] == 1) | (census_df['REGION'] == 2) ) & (census_df['CTYNAME'].str.startswith('Washington')) & (census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])]

# %%
df[['STNAME','CTYNAME']]
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County

# %%
def answer_eight():
    census_df[census_df.SUMLEV != 40]
    df = census_df[((census_df['REGION'] == 1) | (census_df['REGION'] == 2) ) & (census_df['CTYNAME'].str.startswith('Washington')) & (census_df['POPESTIMATE2015'] >  census_df['POPESTIMATE2014'])]    
    return df[['STNAME','CTYNAME']]

# %%
answer_eight()
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County
