# %%
import pandas as pd

census_df = pd.read_csv('census.csv')
census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# 0      40       3         6      1       0   Alabama         Alabama
# 1      50       3         6      1       1   Alabama  Autuaga County
# 2      50       3         6      1       3   Alabama  Baldwin County
# 3      50       3         6      1       5   Alabama  Barbour County
# 4      50       3         6      1       7   Alabama     Bibb County
# 5      40       4         4      2       0  Michigan        Michigan
# 6      50       4         5      3       1  Michigan          mickey
# 7      50       4         6      2       2  Michigan           Mouse
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0        4775636             475827          4785161          2345234
# 1           5678              54632            45234            23431
# 2          36456              34343            34343          1231234
# ...

# %%
df = census_df.set_index("STNAME","CTYNAME")
df
# Out:
#           SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# STNAME
# Alabama       40       3         6      1       0         Alabama
# Alabama       50       3         6      1       1  Autuaga County
# Alabama       50       3         6      1       3  Baldwin County
# Alabama       50       3         6      1       5  Barbour County
# Alabama       50       3         6      1       7     Bibb County
# Michigan      40       4         4      2       0        Michigan
# Michigan      50       4         5      3       1          mickey
# Michigan      50       4         6      2       2           Mouse
#
#           CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# Alabama         4775636             475827          4785161          2345234
# Alabama            5678              54632            45234            23431
# Alabama           36456              34343            34343          1231234
# ...

# %%
import numpy as np
df.apply(np.max,axis=0)
# Out:
# SUMLEV                      50
# REGION                       4
# DIVISION                     6
# STATE                        3
# COUNTY                       7
# CTYNAME                 mickey
# CENSUS2010POP          4775636
# ESTIMATESBASE2010       475827
# POPESTIMATE2010        4785161
# POPESTIMATE2011        4534534
# POPESTIMATE2012         345345
# POPESTIMATE2013        7867867
# POPESTIMATE2014        8786578
# POPESTIMATE2015      234232342
# dtype: object

# %%
census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# 0      40       3         6      1       0   Alabama         Alabama
# 1      50       3         6      1       1   Alabama  Autuaga County
# 2      50       3         6      1       3   Alabama  Baldwin County
# 3      50       3         6      1       5   Alabama  Barbour County
# 4      50       3         6      1       7   Alabama     Bibb County
# 5      40       4         4      2       0  Michigan        Michigan
# 6      50       4         5      3       1  Michigan          mickey
# 7      50       4         6      2       2  Michigan           Mouse
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0        4775636             475827          4785161          2345234
# 1           5678              54632            45234            23431
# 2          36456              34343            34343          1231234
# ...

# %%
census_df.groupby("STNAME")
# Out:
#           SUMLEV  REGION  DIVISION  STATE  COUNTY  CTYNAME  CENSUS2010POP  \
# STNAME
# Alabama        5       5         5      5       5        5              5
# Michigan       3       3         3      3       3        3              3
#
#           ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# Alabama                   5                5                5
# Michigan                  3                3                3
#
#           POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# STNAME
# Alabama                 5                5                5                5
# Michigan                3                3                3                3

# %%
census_df.set_index("STNAME")
# Out:
#           SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# STNAME
# Alabama       40       3         6      1       0         Alabama
# Alabama       50       3         6      1       1  Autuaga County
# Alabama       50       3         6      1       3  Baldwin County
# Alabama       50       3         6      1       5  Barbour County
# Alabama       50       3         6      1       7     Bibb County
# Michigan      40       4         4      2       0        Michigan
# Michigan      50       4         5      3       1          mickey
# Michigan      50       4         6      2       2           Mouse
#
#           CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# Alabama         4775636             475827          4785161          2345234
# Alabama            5678              54632            45234            23431
# Alabama           36456              34343            34343          1231234
# ...

# %%
g = census_df.groupby(level=0,group_keys=False)

# %%
g.nlargest(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-dcf1313df16c> in <module>()
# ----> 1 g.nlargest(3)
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
#     564         # need to setup the selection
#
# ...

# %%
census_df.sort_values(['CENSUS2010POP'],ascending=False).groupby('STNAME').head(3)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# 0      40       3         6      1       0   Alabama         Alabama
# 7      50       4         6      2       2  Michigan           Mouse
# 2      50       3         6      1       3   Alabama  Baldwin County
# 3      50       3         6      1       5   Alabama  Barbour County
# 5      40       4         4      2       0  Michigan        Michigan
# 6      50       4         5      3       1  Michigan          mickey
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0        4775636             475827          4785161          2345234
# 7         454656              64453             6342           345345
# 2          36456              34343            34343          1231234
# 3          34353              34343            34343            56564
# 5           2343                234              234            45345
# ...

# %%
census_df.groupby('STNAME').sort_values('CENSUS2010POP')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-82ed65e0f11a> in <module>()
# ----> 1 census_df.groupby('STNAME').sort_values('CENSUS2010POP')
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
#     564         # need to setup the selection
#
# ...

# %%
census_df.reset_index().set_index('STNAME').groupby('STNAME').apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False)).head(3)
# Out:
#                  index  SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  STNAME
# Alabama Alabama      0      40       3         6      1       0
#         Alabama      2      50       3         6      1       3
#         Alabama      3      50       3         6      1       5
#
#                         CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME  STNAME
# Alabama Alabama         Alabama        4775636             475827
#         Alabama  Baldwin County          36456              34343
#         Alabama  Barbour County          34353              34343
#
#                  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME  STNAME
# Alabama Alabama          4785161          2345234           345245
#         Alabama            34343          1231234               53
#         Alabama            34343            56564           345345
#
#                  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# STNAME  STNAME
# ...

# %%
census_df.groupby('STNAME').apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False))
# Out:
#             SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# STNAME
# Alabama  0      40       3         6      1       0   Alabama         Alabama
#          2      50       3         6      1       3   Alabama  Baldwin County
#          3      50       3         6      1       5   Alabama  Barbour County
#          4      50       3         6      1       7   Alabama     Bibb County
#          1      50       3         6      1       1   Alabama  Autuaga County
# Michigan 7      50       4         6      2       2  Michigan           Mouse
#          5      40       4         4      2       0  Michigan        Michigan
#          6      50       4         5      3       1  Michigan          mickey
#
#             CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama  0        4775636             475827          4785161
#          2          36456              34343            34343
# ...

# %%
census_df = census_df[census_df.SUMLEV != 40]

# %%
census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# 1      50       3         6      1       1   Alabama  Autuaga County
# 2      50       3         6      1       3   Alabama  Baldwin County
# 3      50       3         6      1       5   Alabama  Barbour County
# 4      50       3         6      1       7   Alabama     Bibb County
# 6      50       4         5      3       1  Michigan          mickey
# 7      50       4         6      2       2  Michigan           Mouse
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 1           5678              54632            45234            23431
# 2          36456              34343            34343          1231234
# 3          34353              34343            34343            56564
# 4          34343              34343            34343             5345
# 6            234                234              234          4534534
# ...

# %%
g = census_df.groupby('STNAME').apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3)
g
# Out:
#             SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# STNAME
# Alabama  2      50       3         6      1       3   Alabama  Baldwin County
#          3      50       3         6      1       5   Alabama  Barbour County
#          4      50       3         6      1       7   Alabama     Bibb County
# Michigan 7      50       4         6      2       2  Michigan           Mouse
#          6      50       4         5      3       1  Michigan          mickey
#
#             CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama  2          36456              34343            34343
#          3          34353              34343            34343
#          4          34343              34343            34343
# Michigan 7         454656              64453             6342
#          6            234                234              234
#
#             POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME
# ...

# %%
#census_df.reset_index().set_index('STNAME','CTYNAME')
#census_df.groupby(level=0, group_keys=False).apply(lambda x: x.sort_values('CENSUS2010POP', ascending=False)).groupby(level=0).head(3)

# %%
g
# Out:
#             SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# STNAME
# Alabama  2      50       3         6      1       3   Alabama  Baldwin County
#          3      50       3         6      1       5   Alabama  Barbour County
#          4      50       3         6      1       7   Alabama     Bibb County
# Michigan 7      50       4         6      2       2  Michigan           Mouse
#          6      50       4         5      3       1  Michigan          mickey
#
#             CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama  2          36456              34343            34343
#          3          34353              34343            34343
#          4          34343              34343            34343
# Michigan 7         454656              64453             6342
#          6            234                234              234
#
#             POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME
# ...

# %%
g['STNAME','CTYNAME'].tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-3fe15be00f17> in <module>()
# ----> 1 g['STNAME','CTYNAME'].tolist()
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Gracy\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
# ...

# %%
g
# Out:
#             SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# STNAME
# Alabama  2      50       3         6      1       3   Alabama  Baldwin County
#          3      50       3         6      1       5   Alabama  Barbour County
#          4      50       3         6      1       7   Alabama     Bibb County
# Michigan 7      50       4         6      2       2  Michigan           Mouse
#          6      50       4         5      3       1  Michigan          mickey
#
#             CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama  2          36456              34343            34343
#          3          34353              34343            34343
#          4          34343              34343            34343
# Michigan 7         454656              64453             6342
#          6            234                234              234
#
#             POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME
# ...

# %%
g['CTYNAME'].values.tolist()
# Out:
# ['Baldwin County', 'Barbour County', 'Bibb County', 'Mouse', 'mickey']

# %%
g.values.tolist()
# Out:
# [[50L,
#   3L,
#   6L,
#   1L,
#   3L,
#   'Alabama',
#   'Baldwin County',
#   36456L,
#   34343L,
#   34343L,
#   1231234L,
#   53L,
#   867867L,
#   42342L,
#   234232342L],
#  [50L,
#   3L,
#   6L,
#   1L,
#   5L,
#   'Alabama',
#   'Barbour County',
#   34353L,
#   34343L,
#   34343L,
#   56564L,
#   345345L,
#   7867867L,
#   423L,
#   23423L],
#  [50L,
#   3L,
#   6L,
#   1L,
#   7L,
#   'Alabama',
#   'Bibb County',
#   34343L,
#   34343L,
#   34343L,
#   5345L,
#   345345L,
#   786L,
#   45345L,
#   34534L],
#  [50L,
#   4L,
#   6L,
#   2L,
#   2L,
#   'Michigan',
#   'Mouse',
#   454656L,
#   64453L,
#   6342L,
#   345345L,
#   45345L,
#   234234L,
#   67867L,
#   345345L],
#  [50L,
#   4L,
#   5L,
#   3L,
#   1L,
#   'Michigan',
#   'mickey',
#   234L,
#   234L,
#   234L,
#   4534534L,
#   345345L,
#   34234L,
#   5675L,
#   4534L]]

# %%
list(g['STNAME'])
# Out:
# ['Alabama', 'Alabama', 'Alabama', 'Michigan', 'Michigan']

# %%
g.loc[:,['STNAME','CTYNAME']].values.tolist()
# Out:
# [['Alabama', 'Baldwin County'],
#  ['Alabama', 'Barbour County'],
#  ['Alabama', 'Bibb County'],
#  ['Michigan', 'Mouse'],
#  ['Michigan', 'mickey']]

# %%
 g
# Out:
#             SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# STNAME
# Alabama  2      50       3         6      1       3   Alabama  Baldwin County
#          3      50       3         6      1       5   Alabama  Barbour County
#          4      50       3         6      1       7   Alabama     Bibb County
# Michigan 7      50       4         6      2       2  Michigan           Mouse
#          6      50       4         5      3       1  Michigan          mickey
#
#             CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama  2          36456              34343            34343
#          3          34353              34343            34343
#          4          34343              34343            34343
# Michigan 7         454656              64453             6342
#          6            234                234              234
#
#             POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME
# ...

# %%
census_df.groupby('STNAME').apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3).loc[:,['STNAME','CTYNAME']].values.tolist()
# Out:
# [['Alabama', 'Baldwin County'],
#  ['Alabama', 'Barbour County'],
#  ['Alabama', 'Bibb County'],
#  ['Michigan', 'Mouse'],
#  ['Michigan', 'mickey']]

# %%
#Only looking at the three most populous counties for each state, what are the three most populous states (in order of highest population to lowest population)? Use CENSUS2010POP.
# drop rows with SUMLEV = 40
#This function should return a list of string values.

census_df
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME         CTYNAME  \
# 1      50       3         6      1       1   Alabama  Autuaga County
# 2      50       3         6      1       3   Alabama  Baldwin County
# 3      50       3         6      1       5   Alabama  Barbour County
# 4      50       3         6      1       7   Alabama     Bibb County
# 6      50       4         5      3       1  Michigan          mickey
# 7      50       4         6      2       2  Michigan           Mouse
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 1           5678              54632            45234            23431
# 2          36456              34343            34343          1231234
# 3          34353              34343            34343            56564
# 4          34343              34343            34343             5345
# 6            234                234              234          4534534
# ...

# %%
census_df.groupby('STNAME').apply(lambda x:x.sort_values('CENSUS2010POP',ascending=False)).groupby(level=0).head(3).loc[:,['STNAME','CTYNAME']].values.tolist()
# Out:
# [['Alabama', 'Baldwin County'],
#  ['Alabama', 'Barbour County'],
#  ['Alabama', 'Bibb County'],
#  ['Michigan', 'Mouse'],
#  ['Michigan', 'mickey']]
