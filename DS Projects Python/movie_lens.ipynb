# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'movies.csv', 'tags.csv', 'Untitled.ipynb']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl
import seaborn as sns

# %% [markdown]
# AIM : To suggest movie to the use

# %% [markdown]
# Its a multi class classification problem

# %%
movie_df = pd.read_csv('movies.csv')

# %%
movie_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_df
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
tags_df = pd.read_csv('tags.csv')
tags_df
# Out:
#         userId  movieId                                                tag  \
# 0           18     4141                                        Mark Waters
# 1           65      208                                          dark hero
# 2           65      353                                          dark hero
# 3           65      521                                      noir thriller
# 4           65      592                                          dark hero
# 5           65      668                                          bollywood
# 6           65      898                                   screwball comedy
# 7           65     1248                                      noir thriller
# 8           65     1391                                               mars
# 9           65     1617                                           neo-noir
# 10          65     1694                                              jesus
# ...

# %%
movies_reviewed = tags_df['movieId'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-81048c25fd7b> in <module>
#       1 movies_reviewed = tags_df['movieId'].unique()
# ----> 2 pd.to_dataframe(movies_reviewed)
#
# AttributeError: module 'pandas' has no attribute 'to_dataframe'

# %%
movie_df.loc[movie_df['title'].str.startswith('Jumanji')]
# Out:
#    movieId           title                      genres
# 1        2  Jumanji (1995)  Adventure|Children|Fantasy

# %%
movie_df_genre = movie_df['genres'].str.split('|',expand=True)

# %%
movie_df_genre
# Out:
#                         0          1         2        3         4     5     6  \
# 0               Adventure  Animation  Children   Comedy   Fantasy  None  None
# 1               Adventure   Children   Fantasy     None      None  None  None
# 2                  Comedy    Romance      None     None      None  None  None
# 3                  Comedy      Drama   Romance     None      None  None  None
# 4                  Comedy       None      None     None      None  None  None
# 5                  Action      Crime  Thriller     None      None  None  None
# 6                  Comedy    Romance      None     None      None  None  None
# 7               Adventure   Children      None     None      None  None  None
# 8                  Action       None      None     None      None  None  None
# 9                  Action  Adventure  Thriller     None      None  None  None
# 10                 Comedy      Drama   Romance     None      None  None  None
# ...

# %%
movie = movie_df.join(movie_df_genre)

# %%
movie
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
movie_tags = movie.merge(tags_df,how="outer",left_on='movieId',right_on='movieId')

# %%
movie_tags[movie_tags['movieId'] == 1]
# Out:
#      movieId             title                                       genres  \
# 0          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9          1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 10         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
tags_df[tags_df['movieId'] == 1]
# Out:
#         userId  movieId                                     tag   timestamp
# 3676      1644        1                                 Watched  1417736680
# 4509      1741        1                      computer animation  1183903155
# 4510      1741        1                 Disney animated feature  1183933307
# 4511      1741        1                         Pixar animation  1183934770
# 4512      1741        1  T̩a Leoni does not star in this movie  1245093573
# 12169     2299        1                                   Pixar  1403306852
# 15772     3596        1                               animation  1290312028
# 15773     3596        1                                  family  1290312032
# 15774     3596        1                               Tom Hanks  1290312036
# 25502     6233        1                                   Pixar  1387079572
# 25503     6233        1                                   witty  1387079576
# ...

# %%
movie_tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 473297 entries, 0 to 473296
# Data columns (total 16 columns):
# movieId      473297 non-null int64
# title        473297 non-null object
# genres       473297 non-null object
# 0            473297 non-null object
# 1            387904 non-null object
# 2            251680 non-null object
# 3            110406 non-null object
# 4            32037 non-null object
# 5            7215 non-null object
# 6            2384 non-null object
# 7            47 non-null object
# 8            31 non-null object
# 9            31 non-null object
# userId       465564 non-null float64
# tag          465548 non-null object
# timestamp    465564 non-null float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 61.4+ MB
